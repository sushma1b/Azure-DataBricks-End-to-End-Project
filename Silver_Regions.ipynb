# %%
# reading regions table from the catalog schema table
df = spark.read.table("dec25etlproject.bronze.regions")
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("abfss://silver@sadec25etlproject.dfs.core.windows.net/regions")

# %%
df = spark.read.format("delta")\
    .load("abfss://silver@sadec25etlproject.dfs.core.windows.net/regions")
df.display()

# %%
df = spark.read.format("delta")\
    .load("abfss://silver@sadec25etlproject.dfs.core.windows.net/products")
df.display()

# %%
df = spark.read.format("delta")\
    .load("abfss://silver@sadec25etlproject.dfs.core.windows.net/customers")
df.display()

# %%
df = spark.read.format("delta")\
    .load("abfss://silver@sadec25etlproject.dfs.core.windows.net/orders")
df.display()

# %%
# %sql
CREATE TABLE IF NOT EXISTS dec25etlproject.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@sadec25etlproject.dfs.core.windows.net/regions'
